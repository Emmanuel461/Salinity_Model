# %% [markdown]
# ## Instalation of the libraries requiered and autentication with GEE

# %%
# %pip install -r requirements.txt
# Out:
# Collecting geemap (from -r requirements.txt (line 1))
#   Downloading geemap-0.33.1-py2.py3-none-any.whl.metadata (11 kB)
# Collecting rasterstats (from -r requirements.txt (line 2))
#   Downloading rasterstats-0.19.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: geopandas in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (0.14.4)
# Requirement already satisfied: rasterio in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.3.10)
# Collecting earthengine-api (from -r requirements.txt (line 5))
#   Downloading earthengine_api-0.1.414-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: scikit-learn in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.4.2)
# Collecting treeinterpreter (from -r requirements.txt (line 7))
#   Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting google-auth (from -r requirements.txt (line 8))
#   Downloading google_auth-2.32.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib (from -r requirements.txt (line 9))
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-auth-httplib2 (from -r requirements.txt (line 10))
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-python-client (from -r requirements.txt (line 11))
#   Downloading google_api_python_client-2.139.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting pydrive (from -r requirements.txt (line 13))
#   Downloading PyDrive-1.3.1.tar.gz (987 kB)
#      ---------------------------------------- 0.0/987.4 kB ? eta -:--:--
#      ----- -------------------------------- 133.1/987.4 kB 4.0 MB/s eta 0:00:01
#      ------------ ------------------------- 327.7/987.4 kB 4.1 MB/s eta 0:00:01
#      -------------------------- ----------- 686.1/987.4 kB 6.1 MB/s eta 0:00:01
#      -------------------------------------- 987.4/987.4 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: shapely in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 14)) (2.0.4)
# Requirement already satisfied: seaborn in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 15)) (0.12.2)
# Requirement already satisfied: torch in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 16)) (2.2.0)
# Requirement already satisfied: torchvision in c:\users\jesus\anaconda3\lib\site-packages (from -r requirements.txt (line 17)) (0.15.2a0)
# Collecting torchsummary (from -r requirements.txt (line 18))
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Collecting torchinfo (from -r requirements.txt (line 19))
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Collecting bqplot (from geemap->-r requirements.txt (line 1))
#   Downloading bqplot-0.12.43-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from geemap->-r requirements.txt (line 1))
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting eerepr>=0.0.4 (from geemap->-r requirements.txt (line 1))
#   Downloading eerepr-0.0.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: folium>=0.13.0 in c:\users\jesus\anaconda3\lib\site-packages (from geemap->-r requirements.txt (line 1)) (0.16.0)
# Collecting geocoder (from geemap->-r requirements.txt (line 1))
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ipyevents (from geemap->-r requirements.txt (line 1))
#   Downloading ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser>=0.6.0 (from geemap->-r requirements.txt (line 1))
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet>=0.17.0 (from geemap->-r requirements.txt (line 1))
#   Downloading ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipytree (from geemap->-r requirements.txt (line 1))
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Requirement already satisfied: matplotlib in c:\users\jesus\anaconda3\lib\site-packages (from geemap->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: numpy in c:\users\jesus\anaconda3\lib\site-packages (from geemap->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\jesus\anaconda3\lib\site-packages (from geemap->-r requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: plotly in c:\users\jesus\anaconda3\lib\site-packages (from geemap->-r requirements.txt (line 1)) (5.9.0)
# Collecting pyperclip (from geemap->-r requirements.txt (line 1))
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyshp>=2.1.3 (from geemap->-r requirements.txt (line 1))
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#      ---------------------------------------- 56.0/56.0 kB ? eta 0:00:00
# Collecting python-box (from geemap->-r requirements.txt (line 1))
#   Downloading python_box-7.2.0-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Collecting scooby (from geemap->-r requirements.txt (line 1))
#   Downloading scooby-0.10.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: affine in c:\users\jesus\anaconda3\lib\site-packages (from rasterstats->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: click>7.1 in c:\users\jesus\anaconda3\lib\site-packages (from rasterstats->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: cligj>=0.4 in c:\users\jesus\anaconda3\lib\site-packages (from rasterstats->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: fiona in c:\users\jesus\anaconda3\lib\site-packages (from rasterstats->-r requirements.txt (line 2)) (1.9.6)
# Collecting simplejson (from rasterstats->-r requirements.txt (line 2))
#   Downloading simplejson-3.19.2-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: packaging in c:\users\jesus\anaconda3\lib\site-packages (from geopandas->-r requirements.txt (line 3)) (23.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\jesus\anaconda3\lib\site-packages (from geopandas->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: attrs in c:\users\jesus\anaconda3\lib\site-packages (from rasterio->-r requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: certifi in c:\users\jesus\anaconda3\lib\site-packages (from rasterio->-r requirements.txt (line 4)) (2024.7.4)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\jesus\anaconda3\lib\site-packages (from rasterio->-r requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\jesus\anaconda3\lib\site-packages (from rasterio->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\jesus\anaconda3\lib\site-packages (from rasterio->-r requirements.txt (line 4)) (68.2.2)
# Collecting google-cloud-storage (from earthengine-api->-r requirements.txt (line 5))
#   Downloading google_cloud_storage-2.18.0-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api->-r requirements.txt (line 5))
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests in c:\users\jesus\anaconda3\lib\site-packages (from earthengine-api->-r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jesus\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from google-auth->-r requirements.txt (line 8)) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jesus\anaconda3\lib\site-packages (from google-auth->-r requirements.txt (line 8)) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth->-r requirements.txt (line 8))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib->-r requirements.txt (line 9))
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client->-r requirements.txt (line 11))
#   Downloading google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->-r requirements.txt (line 11))
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting oauth2client>=4.0.0 (from pydrive->-r requirements.txt (line 13))
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: PyYAML>=3.0 in c:\users\jesus\anaconda3\lib\site-packages (from pydrive->-r requirements.txt (line 13)) (6.0.1)
# Requirement already satisfied: filelock in c:\users\jesus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 16)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\jesus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: sympy in c:\users\jesus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 16)) (1.12)
# Requirement already satisfied: networkx in c:\users\jesus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 16)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\jesus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 16)) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\jesus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 16)) (2023.10.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jesus\anaconda3\lib\site-packages (from torchvision->-r requirements.txt (line 17)) (10.2.0)
# Requirement already satisfied: colorama in c:\users\jesus\anaconda3\lib\site-packages (from click>7.1->rasterstats->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: six in c:\users\jesus\anaconda3\lib\site-packages (from fiona->rasterstats->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\jesus\anaconda3\lib\site-packages (from folium>=0.13.0->geemap->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: xyzservices in c:\users\jesus\anaconda3\lib\site-packages (from folium>=0.13.0->geemap->-r requirements.txt (line 1)) (2022.9.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->-r requirements.txt (line 11))
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\jesus\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->-r requirements.txt (line 11)) (3.20.3)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->-r requirements.txt (line 11))
#   Downloading proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\jesus\anaconda3\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: ipywidgets in c:\users\jesus\anaconda3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (7.6.5)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet>=0.17.0->geemap->-r requirements.txt (line 1))
#   Downloading jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.17.0->geemap->-r requirements.txt (line 1))
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jesus\anaconda3\lib\site-packages (from jinja2->torch->-r requirements.txt (line 16)) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jesus\anaconda3\lib\site-packages (from matplotlib->geemap->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jesus\anaconda3\lib\site-packages (from matplotlib->geemap->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jesus\anaconda3\lib\site-packages (from matplotlib->geemap->-r requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jesus\anaconda3\lib\site-packages (from matplotlib->geemap->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jesus\anaconda3\lib\site-packages (from matplotlib->geemap->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\jesus\anaconda3\lib\site-packages (from oauth2client>=4.0.0->pydrive->-r requirements.txt (line 13)) (0.4.8)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jesus\anaconda3\lib\site-packages (from pandas->geemap->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jesus\anaconda3\lib\site-packages (from pandas->geemap->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jesus\anaconda3\lib\site-packages (from requests->earthengine-api->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from requests->earthengine-api->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jesus\anaconda3\lib\site-packages (from requests->earthengine-api->-r requirements.txt (line 5)) (2.0.7)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib->-r requirements.txt (line 9))
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\jesus\anaconda3\lib\site-packages (from bqplot->geemap->-r requirements.txt (line 1)) (5.7.1)
# Requirement already satisfied: future in c:\users\jesus\anaconda3\lib\site-packages (from geocoder->geemap->-r requirements.txt (line 1)) (0.18.3)
# Collecting ratelim (from geocoder->geemap->-r requirements.txt (line 1))
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->earthengine-api->-r requirements.txt (line 5))
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.6.0 (from google-cloud-storage->earthengine-api->-r requirements.txt (line 5))
#   Downloading google_resumable_media-2.7.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->earthengine-api->-r requirements.txt (line 5))
#   Downloading google_crc32c-1.5.0-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from plotly->geemap->-r requirements.txt (line 1)) (8.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jesus\anaconda3\lib\site-packages (from sympy->torch->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: decorator in c:\users\jesus\anaconda3\lib\site-packages (from ratelim->geocoder->geemap->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\jesus\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jesus\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (4.19.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\jesus\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jesus\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jesus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jesus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jesus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\jesus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\jesus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\jesus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\jesus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: wcwidth in c:\users\jesus\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: executing in c:\users\jesus\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jesus\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jesus\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (7.10.0)
# Requirement already satisfied: overrides in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\jesus\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\jesus\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.9.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jesus\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jesus\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\jesus\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1))
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1))
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\jesus\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1))
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1))
#   Downloading webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jesus\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jesus\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: pycparser in c:\users\jesus\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\jesus\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r requirements.txt (line 1)) (1.2.3)
# Downloading geemap-0.33.1-py2.py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.2 MB 12.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.2 MB 6.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 9.8 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 10.0 MB/s eta 0:00:00
# Downloading rasterstats-0.19.0-py3-none-any.whl (16 kB)
# Downloading earthengine_api-0.1.414-py3-none-any.whl (447 kB)
#    ---------------------------------------- 0.0/447.4 kB ? eta -:--:--
#    --------------------------------------- 447.4/447.4 kB 13.7 MB/s eta 0:00:00
# Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl (6.0 kB)
# Downloading google_auth-2.32.0-py2.py3-none-any.whl (195 kB)
#    ---------------------------------------- 0.0/195.5 kB ? eta -:--:--
#    ---------------------------------------- 195.5/195.5 kB ? eta 0:00:00
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_api_python_client-2.139.0-py2.py3-none-any.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    - -------------------------------------- 0.6/12.1 MB 38.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.3/12.1 MB 16.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.9/12.1 MB 15.2 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/12.1 MB 15.6 MB/s eta 0:00:01
#    --------- ------------------------------ 2.9/12.1 MB 14.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.6/12.1 MB 15.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.3/12.1 MB 14.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.1/12.1 MB 14.9 MB/s eta 0:00:01
#    ------------------ --------------------- 5.6/12.1 MB 15.0 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.1 MB 14.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.7/12.1 MB 14.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.1/12.1 MB 13.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.6/12.1 MB 13.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.2/12.1 MB 13.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.8/12.1 MB 13.4 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.1 MB 13.3 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.1 MB 13.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.6/12.1 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.1 MB 13.1 MB/s eta 0:00:01
#    -------------------------------------- - 11.7/12.1 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 12.8 MB/s eta 0:00:00
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading eerepr-0.0.4-py3-none-any.whl (9.7 kB)
# Downloading google_api_core-2.19.1-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 8.1 MB/s eta 0:00:00
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Downloading ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#    ---------------------------------------- 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#    ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading bqplot-0.12.43-py2.py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 16.8 MB/s eta 0:00:01
#    -------------------------------------- - 1.2/1.2 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 13.1 MB/s eta 0:00:00
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.6 kB ? eta -:--:--
#    ---------------------------------------- 98.6/98.6 kB 5.9 MB/s eta 0:00:00
# Downloading google_cloud_storage-2.18.0-py2.py3-none-any.whl (130 kB)
#    ---------------------------------------- 0.0/130.5 kB ? eta -:--:--
#    ---------------------------------------- 130.5/130.5 kB 8.0 MB/s eta 0:00:00
# Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.8 kB ? eta -:--:--
#    ---------------------------------------- 101.8/101.8 kB 6.1 MB/s eta 0:00:00
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------------------- ------------------- 0.7/1.3 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 13.7 MB/s eta 0:00:00
# Downloading python_box-7.2.0-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------------- ---------------- 0.7/1.2 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 15.2 MB/s eta 0:00:00
# Downloading scooby-0.10.0-py3-none-any.whl (18 kB)
# Downloading simplejson-3.19.2-cp311-cp311-win_amd64.whl (75 kB)
#    ---------------------------------------- 0.0/75.3 kB ? eta -:--:--
#    ---------------------------------------- 75.3/75.3 kB ? eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.5.0-cp311-cp311-win_amd64.whl (27 kB)
# Downloading google_resumable_media-2.7.1-py2.py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.2 kB ? eta -:--:--
#    ---------------------------------------- 81.2/81.2 kB ? eta 0:00:00
# Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#    ---------------------------------------- 0.0/220.0 kB ? eta -:--:--
#    --------------------------------------- 220.0/220.0 kB 14.0 MB/s eta 0:00:00
# Downloading jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------- ----------------------- 0.4/1.1 MB 13.9 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.1 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 11.5 MB/s eta 0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB 8.8 MB/s eta 0:00:00
# Downloading proto_plus-1.24.0-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB 2.7 MB/s eta 0:00:00
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: pydrive, pyperclip
#   Building wheel for pydrive (setup.py): started
#   Building wheel for pydrive (setup.py): finished with status 'done'
#   Created wheel for pydrive: filename=PyDrive-1.3.1-py3-none-any.whl size=27465 sha256=adfdeda58b5c2d9bb8318a6895e51604d7c73ced3476b108b64e972529f9141b
#   Stored in directory: c:\users\jesus\appdata\local\pip\cache\wheels\31\d5\09\88865e0059104686eb8365ca1d36a8b27deef34232c3b62c90
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11019 sha256=976785d00fc0a3a7c86df90b4a3cfae7c797408a5d39232c6512a90d7ef4ba02
#   Stored in directory: c:\users\jesus\appdata\local\pip\cache\wheels\e8\e7\56\591cb88ba1783b38c40d584026e766aac9c3a048e34128ce8b
# Successfully built pydrive pyperclip
# Installing collected packages: treeinterpreter, torchsummary, pyperclip, colour, webcolors, uritemplate, uri-template, traittypes, torchinfo, simplejson, scooby, rsa, ratelim, python-box, pyshp, proto-plus, oauthlib, jupyter-leaflet, httplib2, googleapis-common-protos, google-crc32c, fqdn, requests-oauthlib, oauth2client, google-resumable-media, google-auth, geocoder, isoduration, google-auth-oauthlib, google-auth-httplib2, google-api-core, rasterstats, google-cloud-core, google-api-python-client, pydrive, google-cloud-storage, earthengine-api, eerepr, ipytree, ipyleaflet, ipyfilechooser, ipyevents, bqplot, geemap
# Successfully installed bqplot-0.12.43 colour-0.1.5 earthengine-api-0.1.414 eerepr-0.0.4 fqdn-1.5.1 geemap-0.33.1 geocoder-1.38.1 google-api-core-2.19.1 google-api-python-client-2.139.0 google-auth-2.32.0 google-auth-httplib2-0.2.0 google-auth-oauthlib-1.2.1 google-cloud-core-2.4.1 google-cloud-storage-2.18.0 google-crc32c-1.5.0 google-resumable-media-2.7.1 googleapis-common-protos-1.63.2 httplib2-0.22.0 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipytree-0.2.2 isoduration-20.11.0 jupyter-leaflet-0.19.2 oauth2client-4.1.3 oauthlib-3.2.2 proto-plus-1.24.0 pydrive-1.3.1 pyperclip-1.9.0 pyshp-2.3.1 python-box-7.2.0 rasterstats-0.19.0 ratelim-0.1.6 requests-oauthlib-2.0.0 rsa-4.9 scooby-0.10.0 simplejson-3.19.2 torchinfo-1.8.0 torchsummary-1.5.1 traittypes-0.2.1 treeinterpreter-0.2.3 uri-template-1.3.0 uritemplate-4.1.1 webcolors-24.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import google.auth

# Path to the JSON file with the credentials
credentials_path = 'C:/Users/jesus/client_secret_2_775448020170-glgpi5v37ur14of7spbms2gi67g7silt.apps.googleusercontent.com.json'
token_path = 'token.json'

# Authentication using OAuth 2.0 client credentials
def get_credentials():
    credentials = None
    if os.path.exists(token_path):
        with open(token_path, 'r') as token_file:
            credentials = google.oauth2.credentials.Credentials.from_authorized_user_info(
                json.load(token_file)
            )

    if not credentials or not credentials.valid:
        if credentials and credentials.expired and credentials.refresh_token:
            credentials.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                credentials_path,
                scopes=['https://www.googleapis.com/auth/cloud-platform']
            )
            credentials = flow.run_local_server(port=0)

        # Guarda las credenciales para la próxima ejecución
        with open(token_path, 'w') as token_file:
            token_file.write(credentials.to_json())

    return credentials

credentials = get_credentials()


print("Authentication successful")
# Out:
# Authentication successful
