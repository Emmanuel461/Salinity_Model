# %% [markdown]
# # Correlation between all the index and the ECe
#
# ### 1. Call the data for the correlation process
# ### 2. Run the correlation and linear regression process
#
#
# -----------------------------------------------------------------

# %% [markdown]
# ### 1. Call the data for the correlation process

# %%
import pandas as pd

# %%
my_root_dir = "/content/drive/MyDrive/Datos/GEE"
dataframe = pd.read_excel('../DataIntermediate/All_data.xlsx')
dataframe.head(382)
# Out:
#           b1      b2       b3      b4      b5       b6       b7       b8  \
# 0     548.50  707.00   850.00  926.50  1254.0  1325.00  1664.50  2842.00
# 1     541.00  662.00   784.50  844.50  1083.0   967.00  1356.50  2455.50
# 2     491.00  623.50   765.50  818.00  1034.5   903.50  1446.50  2762.50
# 3     607.00  689.00   840.50  885.00  1112.5   983.00  1362.50  2370.00
# 4     585.50  657.00   762.00  800.50   951.5   861.00  1086.50  1832.00
# ..       ...     ...      ...     ...     ...      ...      ...      ...
# 377   974.50  703.75  1257.25  930.25  1528.5  1228.00  1406.75  2492.50
# 378   794.75  445.00   946.75  534.00  1075.0   698.25   819.50  1532.00
# 379   931.25  664.50  1210.50  884.75  1473.0  1163.50  1338.00  2224.75
# 380   882.50  599.50  1174.50  843.50  1389.5  1079.00  1335.00  2600.00
# 381  1023.50  569.00  1314.00  779.50  1422.0  1021.50  1272.00  2438.00
#
#          NDVI        SR  ...  b1_1 (Clay+Silt)  b2_1(Sand_Raster)  \
# 0    0.364127  2.145283  ...          0.850000           0.150000
# 1    0.439585  2.568796  ...          0.519413           0.473399
# 2    0.508677  3.070660  ...          0.654887           0.343329
# 3    0.416839  2.429589  ...          0.524789           0.470715
# 4    0.354755  2.100475  ...          0.517816           0.474641
# ..        ...       ...  ...               ...                ...
# 377  0.344621  2.075156  ...          0.692295           0.310875
# 378  0.360797  2.177036  ...          0.508479           0.489504
# 379  0.313487  1.940419  ...          0.605472           0.394263
# 380  0.413462  2.424643  ...          0.508871           0.488434
# 381  0.413979  2.412872  ...          0.357063           0.650669
#
#      b3_1 (Silt Raster)  b4_1 (Clay Raster    b8_asm   Id         SAR  \
# 0              0.460000           0.390000  0.104167    1   26.926614
# 1              0.337389           0.181547  0.104167    2   86.327645
# 2              0.461192           0.192468  0.104167    3  112.754286
# 3              0.431571           0.093336  0.104167    4  193.130080
# 4              0.407218           0.110598  0.104167    5  126.060248
# ..                  ...                ...       ...  ...         ...
# 377            0.336182           0.356843  0.104167   96   23.296082
# 378            0.404964           0.103152  0.105903   97   63.716873
# 379            0.350643           0.254651  0.104167   98  135.108655
# 380            0.413577           0.095293  0.104167   99  122.818091
# 381            0.244212           0.112711  0.104167  100    3.416785
#
#             CE  Tanbanca  Tabanca_Id
# 0     7.089333    Cafine           1
# 1    29.169333    Cafine           1
# 2    42.417333    Cafine           1
# 3    89.521333    Cafine           1
# 4    57.628000    Cafine           1
# ..         ...       ...         ...
# 377   7.016000  Enchugal           3
# 378  12.658667  Enchugal           3
# 379  69.085333  Enchugal           3
# 380  60.008000  Enchugal           3
# 381   0.392000  Enchugal           3
#
# [382 rows x 115 columns]

# %%
X = pd.DataFrame(dataframe, columns = ['b1','b2','b3','b4','b5','b6','b7','b8','NDVI','SR','GCVI','NDWI','VARI','GNDVI','GRVI','SAVI','VSSI','S1','S2','S3_G1','S3_G2','S4','S5_G1','S5_G2','S6_G1','S6_G2','SI','NDSI','SI1_G1','SI1_G2','SI2_G1','SI2_G2','SI3_G1','SI3_G2',
'Int1_G1','Int1_G2','Int2_G1','Int2_G2','YRS6_G1','YRS6_G2','RS6_G1','RS6_G2','RS1','RS2','RS3_G1','RS3_G2','RS4','RS5_G1','RS5_G2','RNDSI','RNDVI','RSI','RSI1_G1','YRSI1_G1', 'YRSI1_G2', 'YRSI2_G1',
'RSI1_G2','RSI2_G1','RSI2_G2','RSI3_G1','RSI3_G2','RInt1_G1','RInt1_G2','RInt2_G1','RInt2_G2', 'YRS1', 'YRS2', 'YRS3_G1', 'YRS3_G2', 'YRS4', 'YRS5_G1', 'YRS5_G2','YRSI',  'YRSI2_G2', 'YRSI3_G1',
'YRSI3_G2','YRInt1_G1', 'YRInt1_G2', 'YRInt2_G1', 'YRInt2_G2', 'YRNDSI', 'YRNDVI', 'YBS1','YBS2', 'YBS4', 'YBS5_G1', 'YBS5_G2', 'YBSI', 'YGS3', 'YGSI1', 'YGSI2', 'YGSI3','YGInt1', 'YGInt2', 'YNS6_G1',
'YNS6_G2', 'YNSI2_G1', 'YNSI2_G2', 'YNInt2_G1', 'YNInt2_G2','YNNDSI', 'YNNDVI','pc1','pc2','pc3','b1_1 (Clay+Silt)',	'b2_1(Sand_Raster)',	'b3_1 (Silt Raster)',	'b4_1 (Clay Raster','b8_asm']).dropna()
# X = pd.concat([X, coordinates[['x', 'y']]], axis=1)
y = pd.DataFrame(dataframe[["CE"]]).dropna()

# %%
X_corr = X[['b1','b2','b3','b4','b5','b6','b7','b8','NDVI','SR','GCVI','NDWI','VARI','GNDVI','GRVI','SAVI','VSSI','S1','S2','S3_G1','S3_G2','S4','S5_G1','S5_G2','S6_G1','S6_G2','SI','NDSI','SI1_G1','SI1_G2','SI2_G1','SI2_G2','SI3_G1','SI3_G2',
'Int1_G1','Int1_G2','Int2_G1','Int2_G2','YRS6_G1','YRS6_G2','RS6_G1','RS6_G2','RS1','RS2','RS3_G1','RS3_G2','RS4','RS5_G1','RS5_G2','RNDSI','RNDVI','RSI','RSI1_G1','YRSI1_G1', 'YRSI1_G2', 'YRSI2_G1',
'RSI1_G2','RSI2_G1','RSI2_G2','RSI3_G1','RSI3_G2','RInt1_G1','RInt1_G2','RInt2_G1','RInt2_G2', 'YRS1', 'YRS2', 'YRS3_G1', 'YRS3_G2', 'YRS4', 'YRS5_G1', 'YRS5_G2','YRSI',  'YRSI2_G2', 'YRSI3_G1',
'YRSI3_G2','YRInt1_G1', 'YRInt1_G2', 'YRInt2_G1', 'YRInt2_G2', 'YRNDSI', 'YRNDVI', 'YBS1','YBS2', 'YBS4', 'YBS5_G1', 'YBS5_G2', 'YBSI', 'YGS3', 'YGSI1', 'YGSI2', 'YGSI3','YGInt1', 'YGInt2', 'YNS6_G1',
'YNS6_G2', 'YNSI2_G1', 'YNSI2_G2', 'YNInt2_G1', 'YNInt2_G2','YNNDSI', 'YNNDVI','pc1','pc2','pc3','b1_1 (Clay+Silt)',	'b2_1(Sand_Raster)',	'b3_1 (Silt Raster)',	'b4_1 (Clay Raster','b8_asm']]
X_corr.head()
# Out:
#       b1     b2     b3     b4      b5      b6      b7      b8      NDVI  \
# 0  548.5  707.0  850.0  926.5  1254.0  1325.0  1664.5  2842.0  0.364127
# 1  541.0  662.0  784.5  844.5  1083.0   967.0  1356.5  2455.5  0.439585
# 2  491.0  623.5  765.5  818.0  1034.5   903.5  1446.5  2762.5  0.508677
# 3  607.0  689.0  840.5  885.0  1112.5   983.0  1362.5  2370.0  0.416839
# 4  585.5  657.0  762.0  800.5   951.5   861.0  1086.5  1832.0  0.354755
#
#          SR  ...    YNNDSI    YNNDVI       pc1       pc2       pc3  \
# 0  2.145283  ...  0.031445 -0.031445 -0.760700  0.059107 -1.215300
# 1  2.568796  ... -0.059287  0.059287 -0.323238  0.188617 -0.065236
# 2  3.070660  ... -0.074180  0.074180 -0.483269  0.525417 -0.021098
# 3  2.429589  ... -0.059602  0.059602 -0.259339 -0.055724  0.157855
# 4  2.100475  ... -0.048999  0.048999  0.103511 -0.018217  0.400393
#
#    b1_1 (Clay+Silt)  b2_1(Sand_Raster)  b3_1 (Silt Raster)  b4_1 (Clay Raster  \
# 0          0.850000           0.150000            0.460000           0.390000
# 1          0.519413           0.473399            0.337389           0.181547
# 2          0.654887           0.343329            0.461192           0.192468
# 3          0.524789           0.470715            0.431571           0.093336
# 4          0.517816           0.474641            0.407218           0.110598
#
#      b8_asm
# 0  0.104167
# 1  0.104167
# 2  0.104167
# 3  0.104167
# 4  0.104167
#
# [5 rows x 110 columns]

# %%
datos_SB = pd.DataFrame(y, columns=['CE'])
y_corr = datos_SB

# %%
datos_corr = pd.concat([y_corr,X], axis = 1)
datos_corr = pd.DataFrame(datos_corr, columns = ['CE','b1','b2','b3','b4','b5','b6','b7','b8','NDVI','SR','GCVI','NDWI','VARI','GNDVI','GRVI','SAVI','VSSI','S1','S2','S3_G1','S3_G2','S4','S5_G1','S5_G2','S6_G1','S6_G2','SI','NDSI','SI1_G1','SI1_G2','SI2_G1','SI2_G2','SI3_G1','SI3_G2',
'Int1_G1','Int1_G2','Int2_G1','Int2_G2','YRS6_G1','YRS6_G2','RS6_G1','RS6_G2','RS1','RS2','RS3_G1','RS3_G2','RS4','RS5_G1','RS5_G2','RNDSI','RNDVI','RSI','RSI1_G1','YRSI1_G1', 'YRSI1_G2', 'YRSI2_G1',
'RSI1_G2','RSI2_G1','RSI2_G2','RSI3_G1','RSI3_G2','RInt1_G1','RInt1_G2','RInt2_G1','RInt2_G2', 'YRS1', 'YRS2', 'YRS3_G1', 'YRS3_G2', 'YRS4', 'YRS5_G1', 'YRS5_G2','YRSI',  'YRSI2_G2', 'YRSI3_G1',
'YRSI3_G2','YRInt1_G1', 'YRInt1_G2', 'YRInt2_G1', 'YRInt2_G2', 'YRNDSI', 'YRNDVI', 'YBS1','YBS2', 'YBS4', 'YBS5_G1', 'YBS5_G2', 'YBSI', 'YGS3', 'YGSI1', 'YGSI2', 'YGSI3','YGInt1', 'YGInt2', 'YNS6_G1',
'YNS6_G2', 'YNSI2_G1', 'YNSI2_G2', 'YNInt2_G1', 'YNInt2_G2','YNNDSI', 'YNNDVI','pc1','pc2','pc3','b1_1 (Clay+Silt)',	'b2_1(Sand_Raster)',	'b3_1 (Silt Raster)',	'b4_1 (Clay Raster','b8_asm'])

datos_corr.head()
# Out:
#           CE     b1     b2     b3     b4      b5      b6      b7      b8  \
# 0   7.089333  548.5  707.0  850.0  926.5  1254.0  1325.0  1664.5  2842.0
# 1  29.169333  541.0  662.0  784.5  844.5  1083.0   967.0  1356.5  2455.5
# 2  42.417333  491.0  623.5  765.5  818.0  1034.5   903.5  1446.5  2762.5
# 3  89.521333  607.0  689.0  840.5  885.0  1112.5   983.0  1362.5  2370.0
# 4  57.628000  585.5  657.0  762.0  800.5   951.5   861.0  1086.5  1832.0
#
#        NDVI  ...    YNNDSI    YNNDVI       pc1       pc2       pc3  \
# 0  0.364127  ...  0.031445 -0.031445 -0.760700  0.059107 -1.215300
# 1  0.439585  ... -0.059287  0.059287 -0.323238  0.188617 -0.065236
# 2  0.508677  ... -0.074180  0.074180 -0.483269  0.525417 -0.021098
# 3  0.416839  ... -0.059602  0.059602 -0.259339 -0.055724  0.157855
# 4  0.354755  ... -0.048999  0.048999  0.103511 -0.018217  0.400393
#
#    b1_1 (Clay+Silt)  b2_1(Sand_Raster)  b3_1 (Silt Raster)  b4_1 (Clay Raster  \
# 0          0.850000           0.150000            0.460000           0.390000
# 1          0.519413           0.473399            0.337389           0.181547
# 2          0.654887           0.343329            0.461192           0.192468
# 3          0.524789           0.470715            0.431571           0.093336
# 4          0.517816           0.474641            0.407218           0.110598
#
#      b8_asm
# 0  0.104167
# 1  0.104167
# 2  0.104167
# 3  0.104167
# 4  0.104167
#
# [5 rows x 111 columns]

# %% [markdown]
# ### 2. Run the correlation and linear regression process

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Dividir los datos en características (X) y objetivo (y)
X_corr = datos_corr.drop(columns=['CE'])  # Características
y_corr = datos_corr['CE']  # Objetivo

# Inicializar una lista para almacenar los R^2 y las fórmulas de cada modelo
r2_scores = []
p_values = []
formulas = []

# Iterar sobre cada columna
for column in X_corr.columns:
    # Añadir una constante a las características
    X_with_const = sm.add_constant(X_corr[[column]])

    # Ajustar un modelo lineal a la columna actual
    model = sm.OLS(y_corr, X_with_const)
    result = model.fit()

    # Calcular R^2
    r2 = result.rsquared
    r2_scores.append(r2)

    # Obtener el p-value de la característica
    p_value = result.pvalues[column]
    p_values.append(p_value)

    # Obtener los coeficientes del modelo
    coef = result.params[column]
    intercept = result.params['const'] if 'const' in result.params else 0

    # Crear la fórmula del modelo
    formula = f"SAR = {coef:.2f} * {column} + {intercept:.2f}"
    formulas.append(formula)

    # Imprimir R^2, p-value y fórmula del modelo
    print(f"R^2 para {column}: {r2}")
    print(f"p-value para {column}: {p_value}")
    print(f"Fórmula del modelo para {column}: {formula}")
    print("--------------------------")

# Crear un gráfico de barras para mostrar los R^2
plt.figure(figsize=(10, 6))
plt.barh(X_corr.columns, r2_scores, color='skyblue')
plt.xlabel('R^2 Score')
plt.ylabel('Variables')
plt.title('R^2 Score para cada columna')
plt.show()

# Imprimir p-values de los modelos
print("P-values de los modelos:")
for column, p_value in zip(X_corr.columns, p_values):
    print(f"p-value para {column}: {p_value}")

# Imprimir fórmulas de los modelos
print("Fórmulas de los modelos:")
for formula in formulas:
    print(formula)
# Out:
# R^2 para b1: 0.013232802955293943
# p-value para b1: 0.02454955373475692
# Fórmula del modelo para b1: SAR = 0.03 * b1 + 20.85
# --------------------------
# R^2 para b2: 5.8146231944555815e-05
# p-value para b2: 0.8819085875449766
# Fórmula del modelo para b2: SAR = 0.00 * b2 + 44.20
# --------------------------
# R^2 para b3: 0.018806380685970847
# p-value para b3: 0.007270046698341461
# Fórmula del modelo para b3: SAR = 0.03 * b3 + 12.75
# --------------------------
# R^2 para b4: 0.021670033834298663
# p-value para b4: 0.003933592740998617
# Fórmula del modelo para b4: SAR = 0.03 * b4 + 8.42
# --------------------------
# R^2 para b5: 0.016579680069119362
# p-value para b5: 0.011772925939288885
# Fórmula del modelo para b5: SAR = 0.02 * b5 + 10.85
# --------------------------
# R^2 para b6: 0.0038803975485829367
# p-value para b6: 0.22448347558662837
# Fórmula del modelo para b6: SAR = 0.01 * b6 + 30.74
# --------------------------
# R^2 para b7: 0.008361021328620932
# p-value para b7: 0.0742555244142025
# Fórmula del modelo para b7: SAR = 0.02 * b7 + 21.19
# --------------------------
# R^2 para b8: 0.06868250908406381
# p-value para b8: 2.0307988500625322e-07
# Fórmula del modelo para b8: SAR = -0.03 * b8 + 128.54
# --------------------------
# R^2 para NDVI: 0.14040182732146222
# p-value para NDVI: 3.527890747663838e-14
# Fórmula del modelo para NDVI: SAR = -275.60 * NDVI + 118.44
# --------------------------
# R^2 para SR: 0.07376750261754339
# p-value para SR: 6.940172204960785e-08
# Fórmula del modelo para SR: SAR = -43.81 * SR + 122.54
# --------------------------
# R^2 para GCVI: 0.09412048554052221
# p-value para GCVI: 9.077673304782539e-10
# Fórmula del modelo para GCVI: SAR = -30.91 * GCVI + 85.28
# --------------------------
# R^2 para NDWI: 0.11413109022822132
# p-value para NDWI: 1.1880650504314446e-11
# Fórmula del modelo para NDWI: SAR = 183.71 * NDWI + 114.73
# --------------------------
# R^2 para VARI: 0.016102133918644346
# p-value para VARI: 0.013063362105025223
# Fórmula del modelo para VARI: SAR = 50.22 * VARI + 55.69
# --------------------------
# R^2 para GNDVI: 0.11413109022822132
# p-value para GNDVI: 1.1880650504314446e-11
# Fórmula del modelo para GNDVI: SAR = -183.71 * GNDVI + 114.73
# --------------------------
# R^2 para GRVI: 0.09412048045175381
# p-value para GRVI: 9.077683226798058e-10
# Fórmula del modelo para GRVI: SAR = -30.91 * GRVI + 116.19
# --------------------------
# R^2 para SAVI: 0.14041562985298028
# p-value para SAVI: 3.5169772133722646e-14
# Fórmula del modelo para SAVI: SAR = -413.48 * SAVI + 118.45
# --------------------------
# R^2 para VSSI: 0.027122254448166072
# p-value para VSSI: 0.0012364313844100538
# Fórmula del modelo para VSSI: SAR = 0.00 * VSSI + 94.58
# --------------------------
# R^2 para S1: 0.005186808982325375
# p-value para S1: 0.16007479133811855
# Fórmula del modelo para S1: SAR = -67.54 * S1 + 84.73
# --------------------------
# R^2 para S2: 0.00714267887522857
# p-value para S2: 0.09907454296236276
# Fórmula del modelo para S2: SAR = -101.09 * S2 + 18.38
# --------------------------
# R^2 para S3_G1: 0.026220091359558384
# p-value para S3_G1: 0.0014961582430612795
# Fórmula del modelo para S3_G1: SAR = 0.02 * S3_G1 + 11.22
# --------------------------
# R^2 para S3_G2: 0.03056962868183566
# p-value para S3_G2: 0.0005979832559469672
# Fórmula del modelo para S3_G2: SAR = 0.02 * S3_G2 + 7.71
# --------------------------
# R^2 para S4: 0.001291162335765872
# p-value para S4: 0.48378762354009197
# Fórmula del modelo para S4: SAR = 0.01 * S4 + 36.71
# --------------------------
# R^2 para S5_G1: 0.006300905940067603
# p-value para S5_G1: 0.12143126116718436
# Fórmula del modelo para S5_G1: SAR = -0.01 * S5_G1 + 61.85
# --------------------------
# R^2 para S5_G2: 0.00659801617180289
# p-value para S5_G2: 0.11296467133939972
# Fórmula del modelo para S5_G2: SAR = -0.02 * S5_G2 + 67.94
# --------------------------
# R^2 para S6_G1: 0.05375768174295259
# p-value para S6_G1: 4.665264336453009e-06
# Fórmula del modelo para S6_G1: SAR = -0.01 * S6_G1 + 90.86
# --------------------------
# R^2 para S6_G2: 0.05375768174295259
# p-value para S6_G2: 4.665264336453009e-06
# Fórmula del modelo para S6_G2: SAR = -0.01 * S6_G2 + 90.86
# --------------------------
# R^2 para SI: 0.0016094788314806596
# p-value para SI: 0.4343025470261419
# Fórmula del modelo para SI: SAR = 0.43 * SI + 25.91
# --------------------------
# R^2 para NDSI: 0.14040182732146222
# p-value para NDSI: 3.527890747663838e-14
# Fórmula del modelo para NDSI: SAR = 275.60 * NDSI + 118.44
# --------------------------
# R^2 para SI1_G1: 0.012629575409839555
# p-value para SI1_G1: 0.028074961647390533
# Fórmula del modelo para SI1_G1: SAR = 0.02 * SI1_G1 + 16.07
# --------------------------
# R^2 para SI1_G2: 0.010830868645166025
# p-value para SI1_G2: 0.04206108740942598
# Fórmula del modelo para SI1_G2: SAR = 0.02 * SI1_G2 + 19.73
# --------------------------
# R^2 para SI2_G1: 0.0159914936103277
# p-value para SI2_G1: 0.013382453447121865
# Fórmula del modelo para SI2_G1: SAR = -0.01 * SI2_G1 + 87.85
# --------------------------
# R^2 para SI2_G2: 0.014885640384185495
# p-value para SI2_G2: 0.01704648007699473
# Fórmula del modelo para SI2_G2: SAR = -0.01 * SI2_G2 + 84.81
# --------------------------
# R^2 para SI3_G1: 0.009436269547657972
# p-value para SI3_G1: 0.057846546886074594
# Fórmula del modelo para SI3_G1: SAR = 0.01 * SI3_G1 + 19.92
# --------------------------
# R^2 para SI3_G2: 0.008923756323807597
# p-value para SI3_G2: 0.06512639087379656
# Fórmula del modelo para SI3_G2: SAR = 0.01 * SI3_G2 + 22.19
# --------------------------
# R^2 para Int1_G1: 0.01096682242804392
# p-value para Int1_G1: 0.040785438177548934
# Fórmula del modelo para Int1_G1: SAR = 0.02 * Int1_G1 + 17.97
# --------------------------
# R^2 para Int1_G2: 0.009858428816173048
# p-value para Int1_G2: 0.05249745310805986
# Fórmula del modelo para Int1_G2: SAR = 0.02 * Int1_G2 + 20.95
# --------------------------
# R^2 para Int2_G1: 0.004583023437892519
# p-value para Int2_G1: 0.1867266043265891
# Fórmula del modelo para Int2_G1: SAR = -0.01 * Int2_G1 + 68.13
# --------------------------
# R^2 para Int2_G2: 0.004157520457449104
# p-value para Int2_G2: 0.2086066284040389
# Fórmula del modelo para Int2_G2: SAR = -0.01 * Int2_G2 + 66.01
# --------------------------
# R^2 para YRS6_G1: 0.06192765764146091
# p-value para YRS6_G1: 8.412759689953414e-07
# Fórmula del modelo para YRS6_G1: SAR = -0.02 * YRS6_G1 + 112.88
# --------------------------
# R^2 para YRS6_G2: 0.077033769484525
# p-value para YRS6_G2: 3.475616502339502e-08
# Fórmula del modelo para YRS6_G2: SAR = -0.02 * YRS6_G2 + 130.98
# --------------------------
# R^2 para RS6_G1: 0.04459047409911976
# p-value para RS6_G1: 3.173323281796891e-05
# Fórmula del modelo para RS6_G1: SAR = -0.01 * RS6_G1 + 86.56
# --------------------------
# R^2 para RS6_G2: 0.07687476422170647
# p-value para RS6_G2: 3.594746203173958e-08
# Fórmula del modelo para RS6_G2: SAR = -0.02 * RS6_G2 + 120.15
# --------------------------
# R^2 para RS1: 0.018966225609016507
# p-value para RS1: 0.007023942349668746
# Fórmula del modelo para RS1: SAR = -131.68 * RS1 + 112.84
# --------------------------
# R^2 para RS2: 0.020205827903659657
# p-value para RS2: 0.00538118032106158
# Fórmula del modelo para RS2: SAR = -158.33 * RS2 + -5.99
# --------------------------
# R^2 para RS3_G1: 0.03515748141984065
# p-value para RS3_G1: 0.0002283020338318859
# Fórmula del modelo para RS3_G1: SAR = 0.02 * RS3_G1 + 3.86
# --------------------------
# R^2 para RS3_G2: 0.043120493062397625
# p-value para RS3_G2: 4.314819916716429e-05
# Fórmula del modelo para RS3_G2: SAR = 0.02 * RS3_G2 + -2.61
# --------------------------
# R^2 para RS4: 0.00268924157305106
# p-value para RS4: 0.3120585416920927
# Fórmula del modelo para RS4: SAR = 0.01 * RS4 + 31.53
# --------------------------
# R^2 para RS5_G1: 0.0039982337299673265
# p-value para RS5_G1: 0.2175630381278704
# Fórmula del modelo para RS5_G1: SAR = -0.01 * RS5_G1 + 59.58
# --------------------------
# R^2 para RS5_G2: 0.003735253283096873
# p-value para RS5_G2: 0.23337304387282137
# Fórmula del modelo para RS5_G2: SAR = -0.01 * RS5_G2 + 64.77
# --------------------------
# R^2 para RNDSI: 0.2574736570976932
# p-value para RNDSI: 2.1798736360048735e-26
# Fórmula del modelo para RNDSI: SAR = 447.19 * RNDSI + 138.38
# --------------------------
# R^2 para RNDVI: 0.2574736570976932
# p-value para RNDVI: 2.1798736360048735e-26
# Fórmula del modelo para RNDVI: SAR = -447.19 * RNDVI + 138.38
# --------------------------
# R^2 para RSI: 0.004107063370986097
# p-value para RSI: 0.2113957053517264
# Fórmula del modelo para RSI: SAR = 0.71 * RSI + 11.13
# --------------------------
# R^2 para RSI1_G1: 0.016875086294697583
# p-value para RSI1_G1: 0.011040644990961355
# Fórmula del modelo para RSI1_G1: SAR = 0.03 * RSI1_G1 + 9.42
# --------------------------
# R^2 para YRSI1_G1: 0.0186358211059221
# p-value para YRSI1_G1: 0.0075423340689603074
# Fórmula del modelo para YRSI1_G1: SAR = 0.03 * YRSI1_G1 + 10.55
# --------------------------
# R^2 para YRSI1_G2: 0.02108541326681035
# p-value para YRSI1_G2: 0.004457142989109672
# Fórmula del modelo para YRSI1_G2: SAR = 0.03 * YRSI1_G2 + 6.38
# --------------------------
# R^2 para YRSI2_G1: 0.012512882587140117
# p-value para YRSI2_G1: 0.02881538007493939
# Fórmula del modelo para YRSI2_G1: SAR = -0.01 * YRSI2_G1 + 84.66
# --------------------------
# R^2 para RSI1_G2: 0.014676126654608157
# p-value para RSI1_G2: 0.017849313445555404
# Fórmula del modelo para RSI1_G2: SAR = 0.02 * RSI1_G2 + 13.59
# --------------------------
# R^2 para RSI2_G1: 0.012026997332049927
# p-value para RSI2_G1: 0.03212292201187349
# Fórmula del modelo para RSI2_G1: SAR = -0.01 * RSI2_G1 + 82.64
# --------------------------
# R^2 para RSI2_G2: 0.01103278436188182
# p-value para RSI2_G2: 0.040181159586951544
# Fórmula del modelo para RSI2_G2: SAR = -0.01 * RSI2_G2 + 79.79
# --------------------------
# R^2 para RSI3_G1: 0.013107532091356733
# p-value para RSI3_G1: 0.025241982844352664
# Fórmula del modelo para RSI3_G1: SAR = 0.02 * RSI3_G1 + 13.03
# --------------------------
# R^2 para RSI3_G2: 0.012172056279509458
# p-value para RSI3_G2: 0.031096107801585823
# Fórmula del modelo para RSI3_G2: SAR = 0.02 * RSI3_G2 + 16.16
# --------------------------
# R^2 para RInt1_G1: 0.01503110189808421
# p-value para RInt1_G1: 0.01651098090658175
# Fórmula del modelo para RInt1_G1: SAR = 0.03 * RInt1_G1 + 10.99
# --------------------------
# R^2 para RInt1_G2: 0.013397902410761553
# p-value para RInt1_G2: 0.02366683022586591
# Fórmula del modelo para RInt1_G2: SAR = 0.02 * RInt1_G2 + 14.83
# --------------------------
# R^2 para RInt2_G1: 0.0030645289441451062
# p-value para RInt2_G1: 0.2804772804311116
# Fórmula del modelo para RInt2_G1: SAR = -0.01 * RInt2_G1 + 64.51
# --------------------------
# R^2 para RInt2_G2: 0.002735241292670554
# p-value para RInt2_G2: 0.3079500030284266
# Fórmula del modelo para RInt2_G2: SAR = -0.01 * RInt2_G2 + 62.62
# --------------------------
# R^2 para YRS1: 0.03209481233690026
# p-value para YRS1: 0.00043400854053035935
# Fórmula del modelo para YRS1: SAR = -129.61 * YRS1 + 117.82
# --------------------------
# R^2 para YRS2: 0.028493131717468922
# p-value para YRS2: 0.0009258735674776894
# Fórmula del modelo para YRS2: SAR = -145.96 * YRS2 + 3.74
# --------------------------
# R^2 para YRS3_G1: 0.022316743336668554
# p-value para YRS3_G1: 0.003426558747388612
# Fórmula del modelo para YRS3_G1: SAR = 0.01 * YRS3_G1 + 20.28
# --------------------------
# R^2 para YRS3_G2: 0.05494439332933232
# p-value para YRS3_G2: 3.638832275704973e-06
# Fórmula del modelo para YRS3_G2: SAR = 0.03 * YRS3_G2 + -8.76
# --------------------------
# R^2 para YRS4: 0.00572920659711873
# p-value para YRS4: 0.13977001195511665
# Fórmula del modelo para YRS4: SAR = 0.02 * YRS4 + 24.18
# --------------------------
# R^2 para YRS5_G1: 0.000821117760541834
# p-value para YRS5_G1: 0.5766128841626166
# Fórmula del modelo para YRS5_G1: SAR = -0.01 * YRS5_G1 + 53.81
# --------------------------
# R^2 para YRS5_G2: 0.0003641278343372578
# p-value para YRS5_G2: 0.7100652328123315
# Fórmula del modelo para YRS5_G2: SAR = -0.01 * YRS5_G2 + 52.21
# --------------------------
# R^2 para YRSI: 0.0074401802423309515
# p-value para YRSI: 0.09228194808119536
# Fórmula del modelo para YRSI: SAR = 1.01 * YRSI + -2.15
# --------------------------
# R^2 para YRSI2_G2: 0.01208582990864071
# p-value para YRSI2_G2: 0.031702288209784185
# Fórmula del modelo para YRSI2_G2: SAR = -0.01 * YRSI2_G2 + 83.20
# --------------------------
# R^2 para YRSI3_G1: 0.01807622759520766
# p-value para YRSI3_G1: 0.008510807113464016
# Fórmula del modelo para YRSI3_G1: SAR = 0.02 * YRSI3_G1 + 10.56
# --------------------------
# R^2 para YRSI3_G2: 0.019539432746586094
# p-value para YRSI3_G2: 0.006208944062276249
# Fórmula del modelo para YRSI3_G2: SAR = 0.02 * YRSI3_G2 + 7.44
# --------------------------
# R^2 para YRInt1_G1: 0.018421583040949097
# p-value para YRInt1_G1: 0.007899112386474212
# Fórmula del modelo para YRInt1_G1: SAR = 0.03 * YRInt1_G1 + 10.48
# --------------------------
# R^2 para YRInt1_G2: 0.020323132129039245
# p-value para YRInt1_G2: 0.00524750617179583
# Fórmula del modelo para YRInt1_G2: SAR = 0.03 * YRInt1_G2 + 6.83
# --------------------------
# R^2 para YRInt2_G1: 0.002144410241825323
# p-value para YRInt2_G1: 0.36674068537365234
# Fórmula del modelo para YRInt2_G1: SAR = -0.01 * YRInt2_G1 + 61.75
# --------------------------
# R^2 para YRInt2_G2: 0.002195815019961578
# p-value para YRInt2_G2: 0.3610525228898487
# Fórmula del modelo para YRInt2_G2: SAR = -0.01 * YRInt2_G2 + 61.67
# --------------------------
# R^2 para YRNDSI: 0.15153671647524525
# p-value para YRNDSI: 2.8551894667823987e-15
# Fórmula del modelo para YRNDSI: SAR = 242.62 * YRNDSI + 105.80
# --------------------------
# R^2 para YRNDVI: 0.15153671647524525
# p-value para YRNDVI: 2.8551894667823987e-15
# Fórmula del modelo para YRNDVI: SAR = -242.62 * YRNDVI + 105.80
# --------------------------
# R^2 para YBS1: 0.008836678973764278
# p-value para YBS1: 0.06645702936133231
# Fórmula del modelo para YBS1: SAR = 35.17 * YBS1 + 9.58
# --------------------------
# R^2 para YBS2: 0.012303581256981055
# p-value para YBS2: 0.03019455175161995
# Fórmula del modelo para YBS2: SAR = 93.47 * YBS2 + 44.71
# --------------------------
# R^2 para YBS4: 0.009923036879094349
# p-value para YBS4: 0.051726009640780994
# Fórmula del modelo para YBS4: SAR = 0.02 * YBS4 + 19.22
# --------------------------
# R^2 para YBS5_G1: 0.0009466199867551595
# p-value para YBS5_G1: 0.5488325464102036
# Fórmula del modelo para YBS5_G1: SAR = 0.00 * YBS5_G1 + 39.16
# --------------------------
# R^2 para YBS5_G2: 0.0017957650617360654
# p-value para YBS5_G2: 0.40886240337104307
# Fórmula del modelo para YBS5_G2: SAR = 0.01 * YBS5_G2 + 35.12
# --------------------------
# R^2 para YBSI: 0.008015692466441404
# p-value para YBSI: 0.08052775733394213
# Fórmula del modelo para YBSI: SAR = 0.86 * YBSI + -0.19
# --------------------------
# R^2 para YGS3: 0.024747949985676643
# p-value para YGS3: 0.002043496384360773
# Fórmula del modelo para YGS3: SAR = 0.01 * YGS3 + 10.43
# --------------------------
# R^2 para YGSI1: 0.009923036879094349
# p-value para YGSI1: 0.051726009640780994
# Fórmula del modelo para YGSI1: SAR = 0.02 * YGSI1 + 19.22
# --------------------------
# R^2 para YGSI2: 0.010530363726294789
# p-value para YGSI2: 0.045031185777560455
# Fórmula del modelo para YGSI2: SAR = -0.01 * YGSI2 + 79.82
# --------------------------
# R^2 para YGSI3: 0.00960273586681204
# p-value para YGSI3: 0.05567160195322569
# Fórmula del modelo para YGSI3: SAR = 0.01 * YGSI3 + 19.43
# --------------------------
# R^2 para YGInt1: 0.009756409840637303
# p-value para YGInt1: 0.053740389563988855
# Fórmula del modelo para YGInt1: SAR = 0.02 * YGInt1 + 19.33
# --------------------------
# R^2 para YGInt2: 0.00336005942552553
# p-value para YGInt2: 0.25840329508816945
# Fórmula del modelo para YGInt2: SAR = -0.01 * YGInt2 + 64.73
# --------------------------
# R^2 para YNS6_G1: 0.0009466199867551595
# p-value para YNS6_G1: 0.5488325464102036
# Fórmula del modelo para YNS6_G1: SAR = 0.00 * YNS6_G1 + 39.16
# --------------------------
# R^2 para YNS6_G2: 0.0017957650617360654
# p-value para YNS6_G2: 0.40886240337104307
# Fórmula del modelo para YNS6_G2: SAR = 0.01 * YNS6_G2 + 35.12
# --------------------------
# R^2 para YNSI2_G1: 0.012326058590763411
# p-value para YNSI2_G1: 0.030043212707292943
# Fórmula del modelo para YNSI2_G1: SAR = 0.01 * YNSI2_G1 + 15.77
# --------------------------
# R^2 para YNSI2_G2: 0.012223367357422577
# p-value para YNSI2_G2: 0.030741109657263732
# Fórmula del modelo para YNSI2_G2: SAR = 0.01 * YNSI2_G2 + 16.11
# --------------------------
# R^2 para YNInt2_G1: 0.013264132355600866
# p-value para YNInt2_G1: 0.02437947015957533
# Fórmula del modelo para YNInt2_G1: SAR = 0.02 * YNInt2_G1 + 14.80
# --------------------------
# R^2 para YNInt2_G2: 0.01292214318400009
# p-value para YNInt2_G2: 0.026303979153235933
# Fórmula del modelo para YNInt2_G2: SAR = 0.02 * YNInt2_G2 + 15.48
# --------------------------
# R^2 para YNNDSI: 0.012303581256981055
# p-value para YNNDSI: 0.03019455175161995
# Fórmula del modelo para YNNDSI: SAR = -93.47 * YNNDSI + 44.71
# --------------------------
# R^2 para YNNDVI: 0.012303581256981055
# p-value para YNNDVI: 0.03019455175161995
# Fórmula del modelo para YNNDVI: SAR = 93.47 * YNNDVI + 44.71
# --------------------------
# R^2 para pc1: 0.0012914154944443368
# p-value para pc1: 0.48374473535904783
# Fórmula del modelo para pc1: SAR = 2.93 * pc1 + 49.31
# --------------------------
# R^2 para pc2: 0.0643068308267668
# p-value para pc2: 5.102490448479068e-07
# Fórmula del modelo para pc2: SAR = -24.02 * pc2 + 36.47
# --------------------------
# R^2 para pc3: 0.015747093006589163
# p-value para pc3: 0.01411590516278606
# Fórmula del modelo para pc3: SAR = 7.37 * pc3 + 51.10
# --------------------------
# R^2 para b1_1 (Clay+Silt): 0.050928236306361896
# p-value para b1_1 (Clay+Silt): 8.4337695875291e-06
# Fórmula del modelo para b1_1 (Clay+Silt): SAR = -55.01 * b1_1 (Clay+Silt) + 81.05
# --------------------------
# R^2 para b2_1(Sand_Raster): 0.052123996442066556
# p-value para b2_1(Sand_Raster): 6.567082579262294e-06
# Fórmula del modelo para b2_1(Sand_Raster): SAR = 57.02 * b2_1(Sand_Raster) + 25.33
# --------------------------
# R^2 para b3_1 (Silt Raster): 0.01008104206141236
# p-value para b3_1 (Silt Raster): 0.0498892418018324
# Fórmula del modelo para b3_1 (Silt Raster): SAR = 34.96 * b3_1 (Silt Raster) + 32.52
# --------------------------
# R^2 para b4_1 (Clay Raster: 0.18329650489671812
# p-value para b4_1 (Clay Raster: 1.8513886654534312e-18
# Fórmula del modelo para b4_1 (Clay Raster: SAR = -150.69 * b4_1 (Clay Raster + 81.95
# --------------------------
# R^2 para b8_asm: 0.000800725176413164
# p-value para b8_asm: 0.5813873065032512
# Fórmula del modelo para b8_asm: SAR = 2115.07 * b8_asm + -174.27
# --------------------------
# P-values de los modelos:
# p-value para b1: 0.02454955373475692
# p-value para b2: 0.8819085875449766
# p-value para b3: 0.007270046698341461
# p-value para b4: 0.003933592740998617
# p-value para b5: 0.011772925939288885
# p-value para b6: 0.22448347558662837
# p-value para b7: 0.0742555244142025
# p-value para b8: 2.0307988500625322e-07
# p-value para NDVI: 3.527890747663838e-14
# p-value para SR: 6.940172204960785e-08
# p-value para GCVI: 9.077673304782539e-10
# p-value para NDWI: 1.1880650504314446e-11
# p-value para VARI: 0.013063362105025223
# p-value para GNDVI: 1.1880650504314446e-11
# p-value para GRVI: 9.077683226798058e-10
# p-value para SAVI: 3.5169772133722646e-14
# p-value para VSSI: 0.0012364313844100538
# p-value para S1: 0.16007479133811855
# p-value para S2: 0.09907454296236276
# p-value para S3_G1: 0.0014961582430612795
# p-value para S3_G2: 0.0005979832559469672
# p-value para S4: 0.48378762354009197
# p-value para S5_G1: 0.12143126116718436
# p-value para S5_G2: 0.11296467133939972
# p-value para S6_G1: 4.665264336453009e-06
# p-value para S6_G2: 4.665264336453009e-06
# p-value para SI: 0.4343025470261419
# p-value para NDSI: 3.527890747663838e-14
# p-value para SI1_G1: 0.028074961647390533
# p-value para SI1_G2: 0.04206108740942598
# p-value para SI2_G1: 0.013382453447121865
# p-value para SI2_G2: 0.01704648007699473
# p-value para SI3_G1: 0.057846546886074594
# p-value para SI3_G2: 0.06512639087379656
# p-value para Int1_G1: 0.040785438177548934
# p-value para Int1_G2: 0.05249745310805986
# p-value para Int2_G1: 0.1867266043265891
# p-value para Int2_G2: 0.2086066284040389
# p-value para YRS6_G1: 8.412759689953414e-07
# p-value para YRS6_G2: 3.475616502339502e-08
# p-value para RS6_G1: 3.173323281796891e-05
# p-value para RS6_G2: 3.594746203173958e-08
# p-value para RS1: 0.007023942349668746
# p-value para RS2: 0.00538118032106158
# p-value para RS3_G1: 0.0002283020338318859
# p-value para RS3_G2: 4.314819916716429e-05
# p-value para RS4: 0.3120585416920927
# p-value para RS5_G1: 0.2175630381278704
# p-value para RS5_G2: 0.23337304387282137
# p-value para RNDSI: 2.1798736360048735e-26
# p-value para RNDVI: 2.1798736360048735e-26
# p-value para RSI: 0.2113957053517264
# p-value para RSI1_G1: 0.011040644990961355
# p-value para YRSI1_G1: 0.0075423340689603074
# p-value para YRSI1_G2: 0.004457142989109672
# p-value para YRSI2_G1: 0.02881538007493939
# p-value para RSI1_G2: 0.017849313445555404
# p-value para RSI2_G1: 0.03212292201187349
# p-value para RSI2_G2: 0.040181159586951544
# p-value para RSI3_G1: 0.025241982844352664
# p-value para RSI3_G2: 0.031096107801585823
# p-value para RInt1_G1: 0.01651098090658175
# p-value para RInt1_G2: 0.02366683022586591
# p-value para RInt2_G1: 0.2804772804311116
# p-value para RInt2_G2: 0.3079500030284266
# p-value para YRS1: 0.00043400854053035935
# p-value para YRS2: 0.0009258735674776894
# p-value para YRS3_G1: 0.003426558747388612
# p-value para YRS3_G2: 3.638832275704973e-06
# p-value para YRS4: 0.13977001195511665
# p-value para YRS5_G1: 0.5766128841626166
# p-value para YRS5_G2: 0.7100652328123315
# p-value para YRSI: 0.09228194808119536
# p-value para YRSI2_G2: 0.031702288209784185
# p-value para YRSI3_G1: 0.008510807113464016
# p-value para YRSI3_G2: 0.006208944062276249
# p-value para YRInt1_G1: 0.007899112386474212
# p-value para YRInt1_G2: 0.00524750617179583
# p-value para YRInt2_G1: 0.36674068537365234
# p-value para YRInt2_G2: 0.3610525228898487
# p-value para YRNDSI: 2.8551894667823987e-15
# p-value para YRNDVI: 2.8551894667823987e-15
# p-value para YBS1: 0.06645702936133231
# p-value para YBS2: 0.03019455175161995
# p-value para YBS4: 0.051726009640780994
# p-value para YBS5_G1: 0.5488325464102036
# p-value para YBS5_G2: 0.40886240337104307
# p-value para YBSI: 0.08052775733394213
# p-value para YGS3: 0.002043496384360773
# p-value para YGSI1: 0.051726009640780994
# p-value para YGSI2: 0.045031185777560455
# p-value para YGSI3: 0.05567160195322569
# p-value para YGInt1: 0.053740389563988855
# p-value para YGInt2: 0.25840329508816945
# p-value para YNS6_G1: 0.5488325464102036
# p-value para YNS6_G2: 0.40886240337104307
# p-value para YNSI2_G1: 0.030043212707292943
# p-value para YNSI2_G2: 0.030741109657263732
# p-value para YNInt2_G1: 0.02437947015957533
# p-value para YNInt2_G2: 0.026303979153235933
# p-value para YNNDSI: 0.03019455175161995
# p-value para YNNDVI: 0.03019455175161995
# p-value para pc1: 0.48374473535904783
# p-value para pc2: 5.102490448479068e-07
# p-value para pc3: 0.01411590516278606
# p-value para b1_1 (Clay+Silt): 8.4337695875291e-06
# p-value para b2_1(Sand_Raster): 6.567082579262294e-06
# p-value para b3_1 (Silt Raster): 0.0498892418018324
# p-value para b4_1 (Clay Raster: 1.8513886654534312e-18
# p-value para b8_asm: 0.5813873065032512
# Fórmulas de los modelos:
# SAR = 0.03 * b1 + 20.85
# SAR = 0.00 * b2 + 44.20
# SAR = 0.03 * b3 + 12.75
# SAR = 0.03 * b4 + 8.42
# SAR = 0.02 * b5 + 10.85
# SAR = 0.01 * b6 + 30.74
# SAR = 0.02 * b7 + 21.19
# SAR = -0.03 * b8 + 128.54
# SAR = -275.60 * NDVI + 118.44
# SAR = -43.81 * SR + 122.54
# SAR = -30.91 * GCVI + 85.28
# SAR = 183.71 * NDWI + 114.73
# SAR = 50.22 * VARI + 55.69
# SAR = -183.71 * GNDVI + 114.73
# SAR = -30.91 * GRVI + 116.19
# SAR = -413.48 * SAVI + 118.45
# SAR = 0.00 * VSSI + 94.58
# SAR = -67.54 * S1 + 84.73
# SAR = -101.09 * S2 + 18.38
# SAR = 0.02 * S3_G1 + 11.22
# SAR = 0.02 * S3_G2 + 7.71
# SAR = 0.01 * S4 + 36.71
# SAR = -0.01 * S5_G1 + 61.85
# SAR = -0.02 * S5_G2 + 67.94
# SAR = -0.01 * S6_G1 + 90.86
# SAR = -0.01 * S6_G2 + 90.86
# SAR = 0.43 * SI + 25.91
# SAR = 275.60 * NDSI + 118.44
# SAR = 0.02 * SI1_G1 + 16.07
# SAR = 0.02 * SI1_G2 + 19.73
# SAR = -0.01 * SI2_G1 + 87.85
# SAR = -0.01 * SI2_G2 + 84.81
# SAR = 0.01 * SI3_G1 + 19.92
# SAR = 0.01 * SI3_G2 + 22.19
# SAR = 0.02 * Int1_G1 + 17.97
# SAR = 0.02 * Int1_G2 + 20.95
# SAR = -0.01 * Int2_G1 + 68.13
# SAR = -0.01 * Int2_G2 + 66.01
# SAR = -0.02 * YRS6_G1 + 112.88
# SAR = -0.02 * YRS6_G2 + 130.98
# SAR = -0.01 * RS6_G1 + 86.56
# SAR = -0.02 * RS6_G2 + 120.15
# SAR = -131.68 * RS1 + 112.84
# SAR = -158.33 * RS2 + -5.99
# SAR = 0.02 * RS3_G1 + 3.86
# SAR = 0.02 * RS3_G2 + -2.61
# SAR = 0.01 * RS4 + 31.53
# SAR = -0.01 * RS5_G1 + 59.58
# SAR = -0.01 * RS5_G2 + 64.77
# SAR = 447.19 * RNDSI + 138.38
# SAR = -447.19 * RNDVI + 138.38
# SAR = 0.71 * RSI + 11.13
# SAR = 0.03 * RSI1_G1 + 9.42
# SAR = 0.03 * YRSI1_G1 + 10.55
# SAR = 0.03 * YRSI1_G2 + 6.38
# SAR = -0.01 * YRSI2_G1 + 84.66
# SAR = 0.02 * RSI1_G2 + 13.59
# SAR = -0.01 * RSI2_G1 + 82.64
# SAR = -0.01 * RSI2_G2 + 79.79
# SAR = 0.02 * RSI3_G1 + 13.03
# SAR = 0.02 * RSI3_G2 + 16.16
# SAR = 0.03 * RInt1_G1 + 10.99
# SAR = 0.02 * RInt1_G2 + 14.83
# SAR = -0.01 * RInt2_G1 + 64.51
# SAR = -0.01 * RInt2_G2 + 62.62
# SAR = -129.61 * YRS1 + 117.82
# SAR = -145.96 * YRS2 + 3.74
# SAR = 0.01 * YRS3_G1 + 20.28
# SAR = 0.03 * YRS3_G2 + -8.76
# SAR = 0.02 * YRS4 + 24.18
# SAR = -0.01 * YRS5_G1 + 53.81
# SAR = -0.01 * YRS5_G2 + 52.21
# SAR = 1.01 * YRSI + -2.15
# SAR = -0.01 * YRSI2_G2 + 83.20
# SAR = 0.02 * YRSI3_G1 + 10.56
# SAR = 0.02 * YRSI3_G2 + 7.44
# SAR = 0.03 * YRInt1_G1 + 10.48
# SAR = 0.03 * YRInt1_G2 + 6.83
# SAR = -0.01 * YRInt2_G1 + 61.75
# SAR = -0.01 * YRInt2_G2 + 61.67
# SAR = 242.62 * YRNDSI + 105.80
# SAR = -242.62 * YRNDVI + 105.80
# SAR = 35.17 * YBS1 + 9.58
# SAR = 93.47 * YBS2 + 44.71
# SAR = 0.02 * YBS4 + 19.22
# SAR = 0.00 * YBS5_G1 + 39.16
# SAR = 0.01 * YBS5_G2 + 35.12
# SAR = 0.86 * YBSI + -0.19
# SAR = 0.01 * YGS3 + 10.43
# SAR = 0.02 * YGSI1 + 19.22
# SAR = -0.01 * YGSI2 + 79.82
# SAR = 0.01 * YGSI3 + 19.43
# SAR = 0.02 * YGInt1 + 19.33
# SAR = -0.01 * YGInt2 + 64.73
# SAR = 0.00 * YNS6_G1 + 39.16
# SAR = 0.01 * YNS6_G2 + 35.12
# SAR = 0.01 * YNSI2_G1 + 15.77
# SAR = 0.01 * YNSI2_G2 + 16.11
# SAR = 0.02 * YNInt2_G1 + 14.80
# SAR = 0.02 * YNInt2_G2 + 15.48
# SAR = -93.47 * YNNDSI + 44.71
# SAR = 93.47 * YNNDVI + 44.71
# SAR = 2.93 * pc1 + 49.31
# SAR = -24.02 * pc2 + 36.47
# SAR = 7.37 * pc3 + 51.10
# SAR = -55.01 * b1_1 (Clay+Silt) + 81.05
# SAR = 57.02 * b2_1(Sand_Raster) + 25.33
# SAR = 34.96 * b3_1 (Silt Raster) + 32.52
# SAR = -150.69 * b4_1 (Clay Raster + 81.95
# SAR = 2115.07 * b8_asm + -174.27

# %%
import pandas as pd

r2_scores = pd.DataFrame(r2_scores)

# Ordenar los valores de manera ascendente (de menor a mayor)
r2_scores_sorted = r2_scores.sort_values(by=0, ascending=False)  # Reemplaza 0 con el nombre de la columna si tiene un nombre

# Mostrar las primeras filas ordenadas
print(r2_scores_sorted.head(60))
# Out:
#             0
# 50   0.257474
# 49   0.257474
# 108  0.183297
# 81   0.151537
# 80   0.151537
# 15   0.140416
# 8    0.140402
# 27   0.140402
# 11   0.114131
# 13   0.114131
# 10   0.094120
# 14   0.094120
# 39   0.077034
# 41   0.076875
# 9    0.073768
# 7    0.068683
# 103  0.064307
# 38   0.061928
# 68   0.054944
# 24   0.053758
# 25   0.053758
# 106  0.052124
# 105  0.050928
# 40   0.044590
# 45   0.043120
# 44   0.035157
# 65   0.032095
# 20   0.030570
# 66   0.028493
# 16   0.027122
# 19   0.026220
# 88   0.024748
# 67   0.022317
# 3    0.021670
# 54   0.021085
# 77   0.020323
# 43   0.020206
# 75   0.019539
# 42   0.018966
# 2    0.018806
# 53   0.018636
# 76   0.018422
# 74   0.018076
# 52   0.016875
# 4    0.016580
# 12   0.016102
# 30   0.015991
# 104  0.015747
# 61   0.015031
# 31   0.014886
# 56   0.014676
# 62   0.013398
# 98   0.013264
# 0    0.013233
# 59   0.013108
# 99   0.012922
# 28   0.012630
# 55   0.012513
# 96   0.012326
# 101  0.012304

# %%
import seaborn as sns
import numpy as np

# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 12))
# Cambiar el nombre de la columna b1_1 a Clay_Silt
datos_corr.rename(columns={'b1_1 (Clay+Silt)': 'Clay+Silt Raster', 'b2_1(Sand_Raster)':'Sand Raster', 'b3_1 (Silt Raster)':'Silt Raster', 'b4_1 (Clay Raster':'Clay Raster', 'CE': 'ECe'}, inplace=True)


# Seleccionar las columnas de interés y calcular la matriz de correlación
datoscorr = datos_corr[['ECe', 'Clay+Silt Raster', 'Sand Raster', 'Silt Raster', 'Clay Raster','b1','b2','b3','b4','b5','b6','b7','b8','NDVI','SR','GCVI','NDWI','VARI','GNDVI','GRVI','SAVI','VSSI','S1','S2','S3_G1','S3_G2','S4','S5_G1','S5_G2','S6_G1','S6_G2','SI','NDSI','SI1_G1','SI1_G2','SI2_G1','SI2_G2','SI3_G1','SI3_G2',
'Int1_G1','Int1_G2','Int2_G1','Int2_G2','YRS6_G1','YRS6_G2','RS6_G1','RS6_G2','RS1','RS2','RS3_G1','RS3_G2','RS4','RS5_G1','RS5_G2','RNDSI','RNDVI','RSI','RSI1_G1','YRSI1_G1', 'YRSI1_G2', 'YRSI2_G1',
'RSI1_G2','RSI2_G1','RSI2_G2','RSI3_G1','RSI3_G2','RInt1_G1','RInt1_G2','RInt2_G1','RInt2_G2', 'YRS1', 'YRS2', 'YRS3_G1', 'YRS3_G2', 'YRS4', 'YRS5_G1', 'YRS5_G2','YRSI',  'YRSI2_G2', 'YRSI3_G1',
'YRSI3_G2','YRInt1_G1', 'YRInt1_G2', 'YRInt2_G1', 'YRInt2_G2', 'YRNDSI', 'YRNDVI', 'YBS1','YBS2', 'YBS4', 'YBS5_G1', 'YBS5_G2', 'YBSI', 'YGS3', 'YGSI1', 'YGSI2', 'YGSI3','YGInt1', 'YGInt2', 'YNS6_G1',
'YNS6_G2', 'YNSI2_G1', 'YNSI2_G2', 'YNInt2_G1', 'YNInt2_G2','YNNDSI', 'YNNDVI','pc1','pc2','pc3','b8_asm']] # b1_1 (Clay_Silt)	b2_1 (Sand)	b3_1 (Silt)	b4_1 (Clay)

# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 12))

cormat = datoscorr.corr()

# Redondear la matriz de correlación a dos decimales
cormat_rounded = round(cormat, 2)

matrix = np.triu(cormat)

# Ajustar configuraciones de estilo y tamaño de fuente
sns.set(font_scale=1.5)

# Crear el gráfico
ax = sns.heatmap(cormat_rounded, annot=True, fmt='.2f', cmap='RdYlGn', mask=matrix, annot_kws={'size': 15})

# Ajustar los tamaños de las etiquetas de los ejes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Mostrar el gráfico
plt.show()

# %%
# Crear un DataFrame con las correlaciones de SAR
correlation_with_sar = pd.DataFrame(cormat['ECe'])

# Guardar el DataFrame como un archivo Excel
correlation_with_sar.to_excel('../DataIntermediate/correlation_with_CE.xlsx')

# %%
# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 12))

# Cambiar el nombre de la columna b1_1 a Clay_Silt
datos_corr.rename(columns={'b1_1': 'Clay+Silt Raster', 'b2_1':'Sand Raster', 'b3_1':'Silt Raster'}, inplace=True)

# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 12))

# Seleccionar las columnas de interés y calcular la matriz de correlación
datoscorr = datos_corr[['ECe','RNDSI', 'NDSI', 'NDWI','Silt Raster']] # b1_1 (Clay_Silt)	b2_1 (Sand)	b3_1 (Silt)	b4_1 (Clay)

# 'RNDSI', 'NDSI', 'NDWI', 'NDVI','b3_1 (Silt Raster)','b4_1 (Clay Raster'
cormat = datoscorr.corr()

# Redondear la matriz de correlación a dos decimales
cormat_rounded = round(cormat, 2)

matrix = np.triu(cormat)

# Ajustar configuraciones de estilo y tamaño de fuente
sns.set(font_scale=1.5)

# Crear el gráfico
ax = sns.heatmap(cormat_rounded, annot=True, fmt='.2f', cmap='RdYlGn', mask=matrix, annot_kws={'size': 19})

# Ajustar los tamaños de las etiquetas de los ejes
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# Mostrar el gráfico
plt.show()
